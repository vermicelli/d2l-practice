# %%
import d2l
import numpy as np
import pandas as pd
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import data as gdata, loss as gloss, nn

# %% [markdown]
# # Accessing and Reading Data Sets

# %%
train_data = pd.read_csv('../data/house-prices-advanced-regression-techniques/train.csv')
test_data = pd.read_csv('../data/house-prices-advanced-regression-techniques/test.csv')

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
train_data.iloc[0:4, [0, 1, 2, 3, -3, -2, -1]]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0       WD        Normal     208500
# 1   2          20       RL         80.0       WD        Normal     181500
# 2   3          60       RL         68.0       WD        Normal     223500
# 3   4          70       RL         60.0       WD       Abnorml     140000

# %%
all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))
all_features.shape
# Out:
# (2919, 79)

# %% [markdown]
# # Data Preprocessing

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(lambda x: (x - x.mean()) / x.std())
all_features = all_features.fillna(0)

# %%
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (2919, 354)

# %%
n_train = train_data.shape[0]
train_features = nd.array(all_features[:n_train].values)
test_features = nd.array(all_features[n_train:].values)
train_labels = nd.array(train_data.SalePrice.values).reshape((-1, 1))

# %% [markdown]
# # Training

# %%
loss = gloss.L2Loss()

def get_net():
    net = nn.Sequential()
    net.add(nn.Dense(1))
    net.initialize()
    return net

# %%
def log_rmse(net, features, labels):
    clipped_preds = nd.clip(net(features), 1, float('inf'))
    rmse = nd.sqrt(2 * loss(clipped_preds.log(), labels.log()).mean())
    return rmse.asscalar()

# %%
def train(net, train_features, train_labels, test_features, test_labels, 
          num_epochs, learning_rate, weight_decay, batch_size):
    train_ls, test_ls = [], []
    train_iter = gdata.DataLoader(gdata.ArrayDataset(train_features, train_labels), batch_size, shuffle=True)
    trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': learning_rate, 'wd': weight_decay})
    for epoch in range(num_epochs):
        for X, y in train_iter:
            with autograd.record():
                l = loss(net(X), y)
            l.backward()
            trainer.step(batch_size)
        train_ls.append(log_rmse(net, train_features, train_labels))
        if test_labels is not None:
            test_ls.append(log_rmse(net, test_features, test_labels))
    return train_ls, test_ls

# %% [markdown]
# # k-Fold Cross-Validation

# %%
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train, y_train = None, None
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]
        if j == i:
            X_valid, y_valid = X_part, y_part
        elif X_train is None:
            X_train, y_train = X_part, y_part
        else:
            X_train = nd.concat(X_train, X_part, dim=0)
            y_train = nd.concat(y_train, y_part, dim=0)
    return X_train, y_train, X_valid, y_valid

# %%
def k_fold(k, X_train, y_train, num_epochs, learning_rate, weight_decay, batch_size):
    train_l_sum, valid_l_sum = 0, 0
    for i in range(k):
        data = get_k_fold_data(k, i, X_train, y_train)
        net = get_net()
        train_ls, valid_ls = train(net, *data, num_epochs, learning_rate, weight_decay, batch_size)
        train_l_sum += train_ls[-1]
        valid_l_sum += valid_ls[-1]
        if i == 0:
            d2l.semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'rmse',
                        range(1, num_epochs + 1), valid_ls, ['train', 'valid'])
        print('fold %d, train rmse %f, valid rmse %f' % (i, train_ls[-1], valid_ls[-1]))
    return train_l_sum / k, valid_l_sum / k

# %% [markdown]
# # Model Selection

# %%
k, num_epochs, lr, weight_decay, batch_size = 5, 100, 5, 0, 64
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, weight_decay, batch_size)
print('%d-fold validation: avg train rmse: %f, avg valid rmse: %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse 0.169677, valid rmse 0.157043
# fold 1, train rmse 0.162105, valid rmse 0.188754
# fold 2, train rmse 0.163556, valid rmse 0.167898
# fold 3, train rmse 0.167549, valid rmse 0.154678
# fold 4, train rmse 0.162597, valid rmse 0.182864
# 5-fold validation: avg train rmse: 0.165097, avg valid rmse: 0.170247

# %% [markdown]
# # Predict and Submit

# %%
def train_and_pred(train_features, test_features, train_labels, test_data, 
                   num_epochs, lr, weight_decay, batch_size):
    net = get_net()
    train_ls, _ = train(net, train_features, train_labels, None, None, num_epochs, lr, weight_decay, batch_size)
    d2l.semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'rmse')
    print('train rmse %f' % train_ls[-1])
    preds = net(test_features).asnumpy()
    test_data['SalePrice'] = pd.Series(preds.reshape(1, -1)[0])
    submission = pd.concat([test_data['Id'], test_data['SalePrice']], axis=1)
    submission.to_csv('../data/house-prices-advanced-regression-techniques/submission.csv', index=False)

# %%
train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 0.163007

# %% [markdown]
# # Problems

# %% [markdown]
# 1. Submit your predictions for this tutorial to Kaggle. How good are your predictions?

# %% [markdown]
# The LB score of unmodified model above is 0.17438 which is at 3443rd place on the leaderboard.

# %% [markdown]
# 2. Can you improve your model by minimizing the log-price directly? What happens if you try to predict the log price rather than the price?

# %%
def train(net, train_features, train_labels, test_features, test_labels, 
          num_epochs, learning_rate, weight_decay, batch_size):
    train_ls, test_ls = [], []
    train_iter = gdata.DataLoader(gdata.ArrayDataset(train_features, train_labels), batch_size, shuffle=True)
    trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': learning_rate, 'wd': weight_decay})
    for epoch in range(num_epochs):
        for X, y in train_iter:
            with autograd.record():
                l = loss(nd.clip(net(X), 1, float('inf')).log(), y.log())
            l.backward()
            trainer.step(batch_size)
        train_ls.append(log_rmse(net, train_features, train_labels))
        if test_labels is not None:
            test_ls.append(log_rmse(net, test_features, test_labels))
    return train_ls, test_ls

# %%
k, num_epochs, lr, weight_decay, batch_size = 5, 1500, 5, 0, 64
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, weight_decay, batch_size)
print('%d-fold validation: avg train rmse: %f, avg valid rmse: %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse 0.113834, valid rmse 0.143012
# fold 1, train rmse 12.029689, valid rmse 12.034639
# fold 2, train rmse 0.108001, valid rmse 0.139392
# fold 3, train rmse 0.114842, valid rmse 0.120102
# fold 4, train rmse 0.103495, valid rmse 0.151885
# 5-fold validation: avg train rmse: 2.493972, avg valid rmse: 2.517806

# %% [markdown]
# Training process is much slower than when we train against L2 loss function. The best validation RMSLE shows after about 1000 epochs.

# %%
num_epochs = 1000
train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 12.030680

# %% [markdown]
# The LB RMSE is 0.13781, we are at 2182nd place now.

# %% [markdown]
# 3. Is it always a good idea to replace missing values by their mean? Hint - can you construct a situation where the values are not missing at random?

# %% [markdown]
# Using mean value imputation will bring bias to our estimation if the feature that we are trying to impute is correlated to some other features. For example, the GarageYrBlt column is NaN if the house doesn't have garage.

# %% [markdown]
# 4. Find a better representation to deal with missing values. Hint - What happens if you add an indicator variable?

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

train_data = pd.read_csv('../data/house-prices-advanced-regression-techniques/train.csv')
test_data = pd.read_csv('../data/house-prices-advanced-regression-techniques/test.csv')

all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(lambda x: (x - x.mean()) / x.std())

for col in all_features[numeric_features].loc[:, all_features[numeric_features].isna().any()].columns:
    all_features[col+'_ismissing'] = all_features[col].isna().astype('int')
    
all_features = all_features.fillna(0)
all_features = pd.get_dummies(all_features, dummy_na=True)

n_train = train_data.shape[0]
train_features = nd.array(all_features[:n_train].values)
test_features = nd.array(all_features[n_train:].values)
train_labels = nd.array(train_data.SalePrice.values).reshape((-1, 1))

# %%
k, num_epochs, lr, weight_decay, batch_size = 5, 1500, 5, 0, 64
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, weight_decay, batch_size)
print('%d-fold validation: avg train rmse: %f, avg valid rmse: %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse 12.028136, valid rmse 12.040013
# fold 1, train rmse 0.106190, valid rmse 0.143983
# fold 2, train rmse 12.027271, valid rmse 12.044302
# fold 3, train rmse 0.113728, valid rmse 0.121284
# fold 4, train rmse 0.103350, valid rmse 0.149836
# 5-fold validation: avg train rmse: 4.875735, avg valid rmse: 4.899884

# %%
num_epochs = 1000
train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 0.118785

# %% [markdown]
# The LB RMSE is 0.13354, we are at 1894th place now.

# %% [markdown]
# 5. Improve the score on Kaggle by tuning the hyperparameters through k-fold crossvalidation.

# %%
def get_net():
    net = nn.Sequential()
    net.add(nn.Dense(1))
    net.initialize(init.Xavier())
    return net

k, num_epochs, lr, weight_decay, batch_size = 5, 400, 5, 0, 16
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, weight_decay, batch_size)
print('%d-fold validation: avg train rmse: %f, avg valid rmse: %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse 0.122015, valid rmse 0.139203
# fold 1, train rmse 0.111910, valid rmse 0.139903
# fold 2, train rmse 0.112761, valid rmse 0.141615
# fold 3, train rmse 0.123504, valid rmse 0.122193
# fold 4, train rmse 0.109856, valid rmse 0.151636
# 5-fold validation: avg train rmse: 0.116009, avg valid rmse: 0.138910

# %%
num_epochs = 500
train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 0.110058

# %% [markdown]
# The LB RMSE is 0.13221, we are at 1798th place now.

# %% [markdown]
# 6. Improve the score by improving the model (layers, regularization, dropout).

# %%
def get_net():
    net = nn.Sequential()
    net.add(nn.Dense(64, activation='relu'))
    net.add(nn.Dropout(0.2))
    net.add(nn.Dense(1))
    net.initialize(init.Xavier(rnd_type='gaussian', magnitude=6))
    return net

k, num_epochs, lr, weight_decay, batch_size = 5, 200, 0.1, 3e-8, 16
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr, weight_decay, batch_size)
print('%d-fold validation: avg train rmse: %f, avg valid rmse: %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse 0.118817, valid rmse 0.124433
# fold 1, train rmse 0.109950, valid rmse 0.141195
# fold 2, train rmse 0.108096, valid rmse 0.134741
# fold 3, train rmse 0.117972, valid rmse 0.121412
# fold 4, train rmse 0.106754, valid rmse 0.157459
# 5-fold validation: avg train rmse: 0.112318, avg valid rmse: 0.135848

# %%
num_epochs = 200
train_and_pred(train_features, test_features, train_labels, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 0.107894

# %% [markdown]
# The LB RMSE is 0.12493, we are at 1340th place now.

# %% [markdown]
# 7. What happens if we do not standardize the continuous numerical features like we have done in this section?
